# %%
from matplotlib.image import imread

from matplotlib.pyplot import subplots

# %%
cereb = imread('figs/Cerebellum.png')

fig, ax = subplots()

ax.imshow(cereb, cmap='gray');

# %%
type(cereb)
# Out:
# numpy.ndarray

# %%
cereb.shape
# Out:
# (224, 440)

# %%
224*4400
# Out:
# 985600

# %%
cereb[150:200, 200:250]
# Out:
# array([[0.6313726 , 0.7607843 , 0.84705883, ..., 0.24313726, 0.3019608 ,
#         0.42745098],
#        [0.4509804 , 0.43529412, 0.5176471 , ..., 0.32156864, 0.44313726,
#         0.6784314 ],
#        [0.78039217, 0.69411767, 0.5411765 , ..., 0.52156866, 0.67058825,
#         0.7019608 ],
#        ...,
#        [0.44313726, 0.42745098, 0.40392157, ..., 0.41568628, 0.5254902 ,
#         0.49411765],
#        [0.40784314, 0.3137255 , 0.2784314 , ..., 0.34509805, 0.4       ,
#         0.49019608],
#        [0.27058825, 0.27450982, 0.39607844, ..., 0.2901961 , 0.30588236,
#         0.40392157]], dtype=float32)

# %%
fig, ax = subplots()

ax.imshow(cereb[160:190, 210:250], cmap='gray');

# %%
fig, ax = subplots()

ax.imshow(cereb[160:190, 210:250], cmap='bwr_r', interpolation='Gaussian');
