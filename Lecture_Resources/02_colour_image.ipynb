# %%
from matplotlib.image import imread

from matplotlib.pyplot import subplots

# %%
image = imread('figs/Cerebellum2.jpg')

fig, ax = subplots()

ax.imshow(image);

# %%
image.shape
# Out:
# (154, 327, 3)

# %%
fig, ax = subplots()

ax.imshow(image[50:70, 60:100, 2], cmap='gray');

# %%
image[50:70, 60:100, 2]
# Out:
# array([[236, 156, 168, 174, 172, 204, 182, 219,  87, 107, 106, 134,   0,
#          89,  77, 101, 133,   0, 121,  65, 123,  90,  65,  94,  69,  71,
#          93,  81, 109,  93, 105,   0,  72,  98,  48, 110, 104, 104,  93,
#         110],
#        [195, 246, 168, 157, 181, 167, 238, 160, 161, 126, 120, 115,  94,
#           0,  90,  71,   0,   0, 125,  94, 113, 106, 110,  99,  70,  58,
#         100,  73,  74,  94,  96,  63,  65,  92, 101,  95,  87, 103,  97,
#         101],
#        [195, 242, 209, 180,  98, 178, 154, 214, 173, 172, 133,  97,  98,
#          38,   0,  78,  80,  30,  25, 152, 152, 135, 117,   0, 117,  89,
#          50,  97,  51, 103,  95, 112,   0, 115, 110,  89,  94, 104, 102,
#          96],
#        [174, 215, 202, 214, 218,  97, 192, 179, 233, 121, 151,  87,  91,
#          62, 112, 138, 138, 138,  79,   0, 104,  55,   0, 114,  74,  72,
#          90,  92,  76,  49,  90,  98,  77,  20,  62,  95,  99, 107, 103,
#          99],
# ...
